# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import tarfile as tar
import matplotlib.pyplot as plt
import matplotlib
import loompy

# make the text in figures editable in Illustrator
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
#Only run once to extract all files from the tarball
#tar = tarfile.open('SS2_19_009_expression.tar.gz', "r:gz")
#tar.extractall()
#tar.close()

# %%
df = pd.read_csv('rpkms.tab', sep="\t", decimal=",", index_col=0, header = 0)

# %%
df_ercc = pd.read_csv('rpkms-ercc.tab', sep="\t", decimal=",", index_col=0, header = 0)

# %%
df = df.append(df_ercc)

# %%
adata_w = sc.AnnData(df.T)
adata_w.var_names_make_unique()
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
#load metadata and add to adata
meta = pd.read_csv("Meta data.csv", index_col = 0, sep = ";", header = 0, usecols=["well", "Experiment","Animal","Tissue"])
adata_w.obs = meta.loc[adata_w.obs_names]

# %%
adata_w = adata_w[adata_w.obs["Experiment"]=="Vmat2"]
adata_w
# Out:
# View of AnnData object with n_obs × n_vars = 178 × 24582
#     obs: 'Experiment', 'Animal', 'Tissue'

# %%
adata_w.write_loom('vmat2_sscortex.loom')

# %%
sc.pl.highest_expr_genes(adata_w)

# %%
adata_w.var["ERCC"] = [True if gene.startswith("ERCC-") else False for gene in adata_w.var_names]
mito = set(sc.queries.mitochondrial_genes("www.ensembl.org", 'mmusculus'))
adata_w.var["mito"] = [True if gene in mito else False for gene in adata_w.var_names]
# add the total counts per cell as observations-annotation to adata
adata_w.obs['n_counts'] = np.sum(adata_w.X, axis=1)
# Out:
# Trying to set attribute `.var` of view, making a copy.

# %%
sc.pp.calculate_qc_metrics(adata_w, qc_vars=["ERCC", "mito"], inplace=True)

# %%
sns.distplot(adata_w.obs['log1p_total_counts'])
f_count = adata_w.obs_vector('log1p_total_counts') > 11

# %%
sns.jointplot('pct_counts_mito', 'total_counts_mito', data=adata_w.obs, kind="hex")
#f_mito = adata_z.obs_vector('total_counts_mito') < 200
#f_mito_p = adata_z.obs_vector('pct_counts_mito') < 2.5

# %%
sns.distplot(adata_w.obs['pct_counts_mito'])
m_count = adata_w.obs_vector('pct_counts_mito') < 0.1
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
adata_w
# Out:
# AnnData object with n_obs × n_vars = 178 × 24582
#     obs: 'Experiment', 'Animal', 'Tissue', 'Connection', 'n_counts', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_ERCC', 'log1p_total_counts_ERCC', 'pct_counts_ERCC', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito'
#     var: 'ERCC', 'mito', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
sns.jointplot('log1p_n_genes_by_counts', 'pct_counts_in_top_50_genes', data=adata_w.obs, kind="hex")
f_dist = adata_w.obs_vector('pct_counts_in_top_50_genes') < 80 # filter cells with distributed gene counts
f_capt = adata_w.obs_vector('log1p_n_genes_by_counts') > 6.0 # filter cells with broad gene capture

# %%
sns.distplot(adata_w.obs["pct_counts_ERCC"])
f_ercc = adata_w.obs_vector("pct_counts_ERCC") < 10 # less than 10% ERCC counts

# %%
#f_count, f_dist, f_capt, f_ercc
f1 = np.logical_and(f_count, f_dist, m_count)
f2 = np.logical_and(f_capt, f_ercc)
f = np.logical_and(f1,f2)
print(adata_w.shape)
adata_w = adata_w[f]
sc.pp.filter_genes(adata_w, min_cells=3)
print(adata_w.shape)
# Out:
# (178, 24582)
# Trying to set attribute `.var` of view, making a copy.
# (158, 18430)

# %%
sc.pp.normalize_per_cell(adata_w, counts_per_cell_after=np.median(np.apply_over_axes(np.sum, adata_w.X, axes=1)))

# %%
sc.pp.log1p(adata_w)
#adata_w_s = sc.pp.scale(adata_w)

# %%
sc.pp.highly_variable_genes(adata_w, n_top_genes=1000, inplace=True)
#adata_w_s = sc.pp.scale(adata_w)

# %%
sc.pp.pca(adata_w, use_highly_variable=True)
sc.pl.pca_overview(adata_w)
# Out:
# ... storing 'Experiment' as categorical
# ... storing 'Animal' as categorical
# ... storing 'Tissue' as categorical
# ... storing 'Connection' as categorical

# %%
sc.pp.neighbors(adata_w, n_neighbors=10, n_pcs=7)
sc.tl.leiden(adata_w, resolution=1)
sc.tl.umap(adata_w)

# %%
#reassign the cluster names
new_cluster_names = [
    'Vmat2-1', 'Vmat2-2',
    'Vmat2-3', 'Vmat2-4',
    'Vmat2-5', 'Vmat2-6',
    'Vmat2-7', 'Vmat2-8','Glial cells']
adata_w.rename_categories('leiden', new_cluster_names)

# %%
sc.pl.umap(adata_w, color="leiden", save= 'Vmat2_umap_leiden_unprocc.pdf')
# Out:
# WARNING: saving figure to file figures\umapVmat2_umap_leiden_unprocc.pdf

# %%
#reassign the cluster names
new_cluster_names_animals = [
    'Vmat2-Cre;tdTomato 1', 'Vmat2-Cre;tdTomato 2']
adata_w.rename_categories('Animal', new_cluster_names_animals)
sc.pl.umap(adata_w, color="Animal", save= 'Vmat2_umap_animals_unprocc.pdf')
# Out:
# WARNING: saving figure to file figures\umapVmat2_umap_animals_unprocc.pdf

# %%
sc.tl.rank_genes_groups(adata_w, groupby="leiden", n_genes=30)

# %%
sc.tl.dendrogram(adata_w, groupby="leiden")
sc.pl.rank_genes_groups_heatmap(adata_w, n_genes=10, save = 'Vmat2_heatmap_unprocc.pdf')
# Out:
# WARNING: Gene labels are not shown when more than 50 genes are visualized. To show gene labels set `show_gene_labels=True`
# WARNING: saving figure to file figures\heatmapVmat2_heatmap_unprocc.pdf

# %%
#fcer1g, C1qb, Ctss  is expressed by microglia (linnarson mousebrain atlas)
sc.pl.rank_genes_groups_matrixplot(adata_w, groupby="leiden", n_genes=10, save = 'Vmat2_matrix_unprocc.pdf')
# Out:
# WARNING: saving figure to file figures\matrixplotVmat2_matrix_unprocc.pdf

# %%
result = adata_w.uns['rank_genes_groups']
groups = result['names'].dtype.names
pd.DataFrame({group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'scores', 'pvals_adj']}).head(40)
# Out:
#    Vmat2-1_n  Vmat2-1_s  Vmat2-1_p Vmat2-2_n  Vmat2-2_s  Vmat2-2_p Vmat2-3_n  \
# 0     Slc3a2   3.992348   0.837574    Mir100   3.902602   0.960605    Mroh2a
# 1      Abhd3   3.787167   0.837574   Caskin1   3.426349   0.960605     Dnah5
# 2     Cystm1   3.719443   0.837574     Pnisr   3.353322   0.960605       Zan
# 3    Ptplad1   3.709149   0.837574   Metap1d   3.351321   0.960605    Pcdh15
# 4     Gpr146   3.654121   0.837574    Ankra2   3.333409   0.960605      Sfi1
# 5      Kcnn2   3.636266   0.837574     Gria2   3.309437   0.960605     Hmcn1
# 6      Mfge8   3.468228   0.837574      Msi2   3.297264   0.960605     Ddx46
# 7     Ogfod3   3.406287   0.837574      Xist   3.232285   0.960605     Slit2
# 8      Gpr37   3.365084   0.837574     Ddhd1   3.230372   0.960605       Vwf
# 9       Mdh2   3.322645   0.837574    Dnmt3a   3.221252   0.960605      Lrp2
# 19   4.442525   0.079236     Gpr116      ...         0.806271    Slc15a2
# 20   4.386456   0.086721    Pde4dip      ...         0.806271      Bola1
# 21   4.386394   0.086721       Art3      ...         0.806271    Uqcrfs1
# 22   4.353016   0.086392    Rapgef2      ...         0.806271       Cyc1
# 23   4.345371   0.086721     Mroh2a      ...         0.806271     Mfsd2a
# 24   4.311346   0.086721      Csmd3      ...         0.806271      Jagn1
# 25   4.308346   0.086392  Tmem51os1      ...         0.806271    Phyhipl
# 26   4.299879   0.093158      Cped1      ...         0.806271     Atp5a1
# 27   4.298708   0.093158      Cep89      ...         0.806271      Chpt1
# 28   4.292531   0.084587      Stab2      ...         0.806271     Commd3
# 29   4.265213   0.086392     Dab2ip      ...         0.806271     Entpd2
#
#    Vmat2-7_s  Vmat2-7_p      Vmat2-8_n Vmat2-8_s  Vmat2-8_p  Glial cells_n  \
# 0   3.541253   0.858948     ERCC-00074  3.492360   0.860867         Fcer1g
# 1   3.510106   0.858948     ERCC-00130  3.307370   0.860867           C1qc
# 2   3.506908   0.858948     ERCC-00046  2.204847   0.860867         Rnase4
# 3   3.286888   0.858948          Rn45s  2.199303   0.860867           C1qb
# 4   3.282093   0.858948          Phpt1  2.179349   0.860867           C1qa
# 5   3.256001   0.858948           Gnaz  2.177276   0.860867            Fyb
# 6   3.231948   0.858948         Pcsk1n  2.129121   0.860867           Ly6e
# 7   3.229693   0.858948     ERCC-00044  2.099654   0.860867          Fcrls
# 8   3.205659   0.858948         Grcc10  2.092728   0.860867          Csf1r
# 9   3.189542   0.858948         Igflr1  1.945746   0.860867           Ctss
# 10  3.181375   0.858948          Iqcb1  1.930701   0.860867           Aif1
# 11  3.174942   0.858948     ERCC-00004  1.910947   0.860867           Ncf1
# 12  3.172926   0.858948           Eid1  1.899571   0.860867         Tyrobp
# 13  3.134734   0.858948           Nudc  1.889246   0.860867           Cyba
# 14  3.128938   0.858948           Ftl1  1.874303   0.860867        Arhgdib
# 15  3.104707   0.858948          Fads1  1.862277   0.860867        Unc93b1
# 16  3.089538   0.858948         Chchd2  1.861476   0.860867            Trf
# 17  3.046077   0.858948          Stmn1  1.817890   0.860867            Fes
# 18  3.045943   0.858948         Gm4013  1.810065   0.860867          Hpgds
# 19  3.039370   0.858948         Pgrmc2  1.797396   0.860867         Laptm5
# 20  3.036211   0.858948          Paip1  1.772148   0.860867          Cmtm7
# 21  3.027077   0.858948         Mrpl45  1.768654   0.860867            B2m
# 22  3.015502   0.858948           Prkx  1.755281   0.860867           Ctsc
# 23  3.002629   0.858948         Cep120  1.751066   0.860867         Tmsb4x
# 24  2.987142   0.858948           Ddx6  1.736559   0.860867         Adrbk1
# 25  2.947035   0.858948          Padi1  1.726147   0.860867        Alox5ap
# 26  2.946791   0.858948         Anapc5  1.707962   0.860867           Cd37
# 27  2.938143   0.858948         Rpl37a  1.698281   0.860867          Fcgr3
# 28  2.932002   0.858948  4930526I15Rik  1.695214   0.860867          Hmha1
# 29  2.918434   0.858948          Gsk3b  1.688379   0.860867           Ly86
#
#    Glial cells_s  Glial cells_p
# 0      25.421968   1.708723e-07
# 1      23.729359   8.151696e-05
# 2      19.234217   7.125127e-06
# 3      17.889894   8.151696e-05
# 4      17.696281   9.582185e-05
# 5      17.324377   7.125127e-06
# 6      15.055627   5.742699e-04
# 7      14.733638   2.791901e-05
# 8      14.454198   2.743430e-05
# 9      13.787375   3.133590e-05
# 10     13.634285   4.320519e-04
# 11     12.585761   6.220234e-04
# 12     12.388424   8.283192e-05
# 13      9.642499   1.473080e-02
# 14      9.409437   8.613911e-04
# 15      8.726768   2.124407e-03
# 16      7.743977   4.851094e-03
# 17      7.681937   2.269335e-02
# 18      7.188159   1.286196e-02
# 19      6.827815   8.344492e-02
# 20      6.636736   5.268478e-02
# 21      6.253642   1.023828e-01
# 22      6.241476   8.831022e-02
# 23      6.088972   1.023828e-01
# 24      5.771975   9.131397e-02
# 25      5.544748   1.374796e-01
# 26      5.537268   1.368292e-01
# 27      5.531914   1.368292e-01
# 28      5.400720   1.368292e-01
# 29      5.382625   1.368292e-01
#
# [30 rows x 27 columns]

# %%
not_microglia = [False if group == "Glial cells" else True for group in adata_w.obs["leiden"]]
adata_w = adata_w[not_microglia]

# %%
sc.pp.highly_variable_genes(adata_w, n_top_genes=1000, inplace=True)
#adata_w_s = sc.pp.scale(adata_w)
# Out:
# Trying to set attribute `.var` of view, making a copy.

# %%
sc.pp.pca(adata_w, use_highly_variable=True)
sc.pl.pca_overview(adata_w)

# %%
sc.pp.neighbors(adata_w, n_neighbors=10, n_pcs=9)
sc.tl.leiden(adata_w, resolution=1)

sc.tl.umap(adata_w)
sc.pl.umap(adata_w, color= 'leiden')

# %%
#reassign the cluster names
new_cluster_names_procc = [
    'Vmat2-1 (Mroh2a, Dux, Sf11)', 'Vmat2-2',
    'Vmat2-3', 'Vmat2-4',
    'Vmat2-5', 'Vmat2-6',
    'Vmat2-7']

adata_w.rename_categories('leiden', new_cluster_names_procc)
sc.pl.umap(adata_w, color= 'leiden', save = 'Vmat2_UMAP_procc_leiden.pdf' )
# Out:
# Omitting rank_genes_groups/scores as old categories do not match.
# Omitting rank_genes_groups/names as old categories do not match.
# Omitting rank_genes_groups/logfoldchanges as old categories do not match.
# Omitting rank_genes_groups/pvals as old categories do not match.
# Omitting rank_genes_groups/pvals_adj as old categories do not match.
# WARNING: saving figure to file figures\umapVmat2_UMAP_procc_leiden.pdf

# %%
sc.pl.umap(adata_w, color= 'Animal', save ='Vmat2_UMAP_procc_animals.pdf' )
# Out:
# WARNING: saving figure to file figures\umapVmat2_UMAP_procc_animals.pdf

# %%
adata_w
# Out:
# AnnData object with n_obs × n_vars = 151 × 18430
#     obs: 'Experiment', 'Animal', 'Tissue', 'Connection', 'n_counts', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_ERCC', 'log1p_total_counts_ERCC', 'pct_counts_ERCC', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'leiden'
#     var: 'ERCC', 'mito', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'pca', 'neighbors', 'leiden', 'leiden_colors', 'Animal_colors', 'rank_genes_groups', 'dendrogram_leiden'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'

# %%
sc.pl.highest_expr_genes(adata_w, n_top = 50, save ='Vmat2_highest_exp_genes.pdf')
# Out:
# WARNING: saving figure to file figures\highest_expr_genesVmat2_highest_exp_genes.pdf

# %%
sc.tl.rank_genes_groups(adata_w, groupby="leiden", n_genes=30)
sc.tl.dendrogram(adata_w, groupby="leiden")
sc.pl.rank_genes_groups_heatmap(adata_w, n_genes=10, save = 'Vmat2_heatmap_procc_leiden.pdf')
# Out:
# WARNING: Gene labels are not shown when more than 50 genes are visualized. To show gene labels set `show_gene_labels=True`
# WARNING: saving figure to file figures\heatmapVmat2_heatmap_procc_leiden.pdf

# %%
sc.pl.rank_genes_groups_matrixplot(adata_w, groupby="leiden", n_genes=8, save = 'Vmat2_matrix_procc.pdf')
# Out:
# WARNING: saving figure to file figures\matrixplotVmat2_matrix_procc.pdf

# %%
result = adata_w.uns['rank_genes_groups']
groups = result['names'].dtype.names
pd.DataFrame({group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'scores', 'pvals_adj']}).head(40)
# Out:
#    Vmat2-1 (Mroh2a, Dux, Sf11)_n  Vmat2-1 (Mroh2a, Dux, Sf11)_s  \
# 0                         Mroh2a                       9.078009
# 1                            Dux                       7.690699
# 2                           Sfi1                       7.675394
# 3                           Lrp2                       7.660881
# 4                          Dnah8                       6.951270
# 5                         Piezo2                       6.777009
# 6                          Fras1                       6.646269
# 7                           Cubn                       6.641744
# 8                         Spag17                       6.541652
# 9                          Dnah5                       6.379199
# 10                       Pkhd1l1                       6.122749
# 11                          Ryr3                       6.095808
# 12                         Hmcn1                       5.966500
# 13                        Pcnxl2                       5.960292
# 14                         Csmd2                       5.807199
# 15                           Ttn                       5.736941
# 16                         Hydin                       5.682411
# 17                         Pkhd1                       5.636695
# 18                           Neb                       5.629511
# 19                        Dnah10                       5.582553
# 20                         Tdrd9                       5.566036
# 21                          Adgb                       5.482839
# 22                           Zan                       5.458548
# 23                          Mpp4                       5.441799
# 24                           Vwf                       5.433646
# 25                         Dnah2                       5.361536
# 26                         Csmd3                       5.348287
# 27                        Efcab6                       5.347706
# 28                         Cgnl1                       5.339675
# 29                        Pcdh15                       5.331636
#
#     Vmat2-1 (Mroh2a, Dux, Sf11)_p      Vmat2-2_n  Vmat2-2_s  Vmat2-2_p  \
# 0                    5.726533e-08         Tmem80   2.843378   0.804475
# 1                    1.259108e-05        Mpv17l2   2.740670   0.804475
# 2                    8.144190e-06        Sparcl1   2.733713   0.804475
# 3                    3.274939e-05         Tspan7   2.690546   0.804475
# 4                    1.634280e-04           Dlg5   2.628393   0.804475
# 5                    2.474544e-04           Cst3   2.612069   0.804475
# 6                    2.511485e-04  1600012H06Rik   2.498258   0.804475
# 7                    2.095957e-04            Ptn   2.434811   0.804475
# 8                    4.517517e-04  0610031J06Rik   2.412712   0.804475
# 9                    2.511485e-04          Gstm5   2.397018   0.804475
# 10                   1.031265e-03         Tmem47   2.328501   0.804475
# 11                   4.517517e-04        Mir3076   2.229679   0.804475
# 12                   1.008768e-03       AI450353   2.228159   0.804475
# 13                   1.558863e-03         Trafd1   2.214775   0.804475
# 14                   1.081935e-03          Ttyh1   2.152632   0.804475
# 15                   5.961052e-04        Slc15a2   2.150336   0.804475
# 16                   1.008768e-03           Gga1   2.114833   0.804475
# 17                   2.482448e-03           Cul7   2.104356   0.804475
# 18                   1.008768e-03           Rpl9   2.096200   0.804475
# 19                   2.159543e-03           Scg3   2.079555   0.804475
# 26        Ccdc88a  2.406773   0.958961
# 27         Zfp532  2.381790   0.958961
# 28           Fbn2  2.372181   0.958961
# 29           Xist  2.365913   0.958961
#
# [30 rows x 21 columns]

# %%
[name for name in adata_w.var_names if name.startswith('Ht')]
# Out:
# ['Htr2b',
#  'Htr6',
#  'Htr1d',
#  'Htt',
#  'Htr5a',
#  'Htra3',
#  'Htra2',
#  'Htra1',
#  'Htatip2',
#  'Htra4',
#  'Htr3a',
#  'Htr3b',
#  'Htr2c',
#  'Htatsf1',
#  'Htr1a',
#  'Htr2a',
#  'Htr1f',
#  'Htr4']

# %%
group_labels = ['Vmat2', 'Serotonin synthesis', 'Excitatory markers', 'Inhibitory marker', 
              'Layer 2/3 markers', 'Layer 4 markers', 'Layer 4/5 marker', 'Layer 6 markers',
               'Inhibitory interneuron markers']
group_position = [(0,0), (1,3), (4,6), (7,7), (8,12),(13,16),(17,17), (18,19), (20,23)]

marker_genes = ['Slc18a2', 'Tph1', 'Tph2', 'Ddc', 'Slc17a6', 'Slc17a7', 'Slc17a8', 'Gad1',
                'Calb1', 'Pvrl3', 'Npnt', 'Ddn', 'Rasgrf2', 'Scnn1a', 'Rorb',
                'Kcnab3', 'Kcnk2','Plcxd2', 'Foxp2', 'Syt6', 'Sst', 'Htr3a','Pvalb', 'Cck']

sc.pl.stacked_violin(adata_w, var_names = marker_genes, var_group_labels = group_labels, var_group_positions = group_position,
                     stripplot = True, jitter = 0.4, palette = "RdBu", save = 'Vmat2_violin_target_genes.pdf')

# Inhibitory marker VIP not detected
# Out:
# WARNING: saving figure to file figures\stacked_violinVmat2_violin_target_genes.pdf

# %%
sc.pl.heatmap(adata_w, marker_genes, groupby='leiden', var_group_labels = group_labels, var_group_positions = group_position, save = 'vmat2_heatmap_marker_genes.pdf')
# Out:
# WARNING: saving figure to file figures\heatmapvmat2_heatmap_marker_genes.pdf
# GridSpec(2, 4, height_ratios=[0.15, 6], width_ratios=[0.2, 7.199999999999999, 0, 0.2])

# %%
sc.pl.dotplot(adata_w, var_names = marker_genes, var_group_labels = group_labels, var_group_positions = group_position,
                     color_map = "Purples", save = 'Vmat2_dotplot_target_genes.pdf')
# Out:
# WARNING: saving figure to file figures\dotplotVmat2_dotplot_target_genes.pdf
# GridSpec(2, 5, height_ratios=[0.5, 10], width_ratios=[9.1, 0, 0.2, 0.5, 0.25])

# %%
"""function for calculating the percentage of cells expressing gene of interest"""
def percentage_exp(adata, genes):
    per_list = []
    for gene in genes:
        percentage = len(adata[adata[:, gene].X > 0.25])/len(adata.X)
        per_list.append((gene, percentage*100))
    return sorted(per_list, key=lambda tup: tup[1], reverse = True)

"""function for calculating the number of cells expressing gene of interest"""
def number_exp(adata, genes):
    num_list = []
    for gene in genes:
        percentage = len(adata[adata[:, gene].X > 0.25])/len(adata.X)
        num_list.append((gene,percentage*len(adata.X)))
    return sorted(num_list, key=lambda tup: tup[1], reverse = True)

# %%
percentage_exp(adata_w, marker_genes)
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\anndata\core\anndata.py:846: FutureWarning: In anndata v0.7+, arrays contained within an AnnData object will maintain their dimensionality. For example, prior to v0.7 `adata[0, 0].X` returned a scalar and `adata[0, :]` returned a 1d array, post v0.7 they will return two dimensional arrays. If you would like to get a one dimensional array from your AnnData object, consider using the `adata.obs_vector`, `adata.var_vector` methods or accessing the array directly.
#   warn_flatten()
# [('Rorb', 92.71523178807946),
#  ('Pvrl3', 40.397350993377486),
#  ('Slc18a2', 25.165562913907287),
#  ('Kcnk2', 23.841059602649008),
#  ('Foxp2', 11.258278145695364),
#  ('Ddc', 9.933774834437086),
#  ('Plcxd2', 9.933774834437086),
#  ('Tph2', 7.9470198675496695),
#  ('Ddn', 7.9470198675496695),
#  ('Slc17a8', 7.28476821192053),
#  ('Npnt', 7.28476821192053),
#  ('Calb1', 5.960264900662252),
#  ('Syt6', 5.298013245033113),
#  ('Slc17a6', 4.635761589403973),
#  ('Scnn1a', 4.635761589403973),
#  ('Kcnab3', 4.635761589403973),
#  ('Tph1', 3.3112582781456954),
#  ('Slc17a7', 3.3112582781456954),
#  ('Gad1', 3.3112582781456954),
#  ('Rasgrf2', 3.3112582781456954),
#  ('Htr3a', 3.3112582781456954),
#  ('Pvalb', 3.3112582781456954),
#  ('Sst', 1.9867549668874174),
#  ('Cck', 1.9867549668874174)]

# %%
number_exp(adata_w, marker_genes)
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\anndata\core\anndata.py:846: FutureWarning: In anndata v0.7+, arrays contained within an AnnData object will maintain their dimensionality. For example, prior to v0.7 `adata[0, 0].X` returned a scalar and `adata[0, :]` returned a 1d array, post v0.7 they will return two dimensional arrays. If you would like to get a one dimensional array from your AnnData object, consider using the `adata.obs_vector`, `adata.var_vector` methods or accessing the array directly.
#   warn_flatten()
# [('Rorb', 140.0),
#  ('Pvrl3', 61.0),
#  ('Slc18a2', 38.0),
#  ('Kcnk2', 36.0),
#  ('Foxp2', 17.0),
#  ('Ddc', 14.999999999999998),
#  ('Plcxd2', 14.999999999999998),
#  ('Tph2', 12.0),
#  ('Ddn', 12.0),
#  ('Slc17a8', 11.0),
#  ('Npnt', 11.0),
#  ('Calb1', 9.0),
#  ('Syt6', 8.0),
#  ('Slc17a6', 7.0),
#  ('Scnn1a', 7.0),
#  ('Kcnab3', 7.0),
#  ('Tph1', 5.0),
#  ('Slc17a7', 5.0),
#  ('Gad1', 5.0),
#  ('Rasgrf2', 5.0),
#  ('Htr3a', 5.0),
#  ('Pvalb', 5.0),
#  ('Sst', 3.0),
#  ('Cck', 3.0)]

# %%
# importing protein datatbase file from UniProt
targets_families = pd.read_csv('targets_and_families.csv')
targets_families.head()
# Out:
#    Type  Family id                    Family name  Target id  \
# 0  gpcr          1  5-Hydroxytryptamine receptors          1
# 1  gpcr          1  5-Hydroxytryptamine receptors          2
# 2  gpcr          1  5-Hydroxytryptamine receptors          3
# 3  gpcr          1  5-Hydroxytryptamine receptors          4
# 4  gpcr          1  5-Hydroxytryptamine receptors          5
#
#                   Target name Subunits Target systematic name  \
# 0  5-HT<sub>1A</sub> receptor      NaN                    NaN
# 1  5-HT<sub>1B</sub> receptor      NaN                    NaN
# 2  5-HT<sub>1D</sub> receptor      NaN                    NaN
# 3  5-ht<sub>1e</sub> receptor      NaN                    NaN
# 4  5-HT<sub>1F</sub> receptor      NaN                    NaN
#
#   Target abbreviated name                                           synonyms  \
# 0                     NaN  ADRBRL1|5-HT1A|ADRB2RL1|serotonin receptor 1A|...
# 1                     NaN  5-HT1B|5-HT1DB|HTR1D2|5-HT1B serotonin recepto...
# 2                     NaN  5-HT<sub>1D&alpha;</sub>|HTRL|5-HT1D|HT1DA|ser...
# 3                     NaN  5-HT<sub>1E</sub><sub>&alpha;</sub>|5-HT1E|5-h...
# 4                     NaN  5-HT<sub>1E&beta;</sub>|5-HT<sub>6</sub>|5-HT1...
#
#   HGNC id        ...        Rat SwissProt Rat Entrez Gene     MGI id  \
# 0    5286        ...               P19327           24473  MGI:96273
# 1    5287        ...               P28564           25075  MGI:96274
# 2    5289        ...               P28565           25323  MGI:96276
# 3    5291        ...                  NaN             NaN        NaN
# 4    5292        ...               P30940           60448  MGI:99842
#
#   MGI symbol                                     MGI name  \
# 0      Htr1a  5-hydroxytryptamine (serotonin) receptor 1A
# 1      Htr1b  5-hydroxytryptamine (serotonin) receptor 1B
# 2      Htr1d  5-hydroxytryptamine (serotonin) receptor 1D
# 3        NaN                                          NaN
# 4      Htr1f  5-hydroxytryptamine (serotonin) receptor 1F
#
#   Mouse genetic localisation Mouse nucleotide RefSeq Mouse protein RefSeq  \
# 0                    13 D2.1               NM_008308            NP_032334
# 1                       9 E1               NM_010482            NP_034612
# 2                       4 D3               NM_008309            NP_032335
# 3                        NaN                     NaN                  NaN
# 4                    16 C1.3               NM_008310            NP_032336
#
#   Mouse SwissProt Mouse Entrez Gene
# 0          Q64264             15550
# 1          P28334             15551
# 2          Q61224             15552
# 3             NaN               NaN
# 4          Q02284             15557
#
# [5 rows x 33 columns]

# %%
"""function for extracting the genes of interest depending on the category of receptor type"""
def rec_type_list(prot_df, rec_type):
 #   for rec_type in rec_types:
    prot_df = prot_df[prot_df['Type'] == rec_type] #isolate the data having the receptor type of interest from protein dataframe 
    prot_tuple = tuple(prot_df.loc[:,'MGI symbol'].dropna()); #making a tuple of the gene names från the protein name dataframe
    prot_list = [gene for gene in adata_w.var_names if gene.startswith(prot_tuple)] #to ensure gene in adata object, only have list with the genes existing in the adata object
    return prot_list

# %%
#lists of all genes from target receptor type
gpcr_list = rec_type_list(targets_families, 'gpcr')
lgic_list = rec_type_list(targets_families, 'lgic')

# %%
percent_lgic = pd.DataFrame(percentage_exp(adata_w, lgic_list), columns = ['gene_name', 'percent'])
print(percent_lgic[:51])

top_lgig = percent_lgic['gene_name'][:41]
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\anndata\core\anndata.py:846: FutureWarning: In anndata v0.7+, arrays contained within an AnnData object will maintain their dimensionality. For example, prior to v0.7 `adata[0, 0].X` returned a scalar and `adata[0, :]` returned a 1d array, post v0.7 they will return two dimensional arrays. If you would like to get a one dimensional array from your AnnData object, consider using the `adata.obs_vector`, `adata.var_vector` methods or accessing the array directly.
#   warn_flatten()
#    gene_name    percent
# 0      Gria2  93.377483
# 1     Grin2c  93.377483
# 2     Gabrb1  86.092715
# 3      Itpr2  80.794702
# 4     Gabrg1  66.887417
# 5      Grik5  54.304636
# 6       Glrb  51.655629
# 7     Gabra2  42.384106
# 8     Grin2b  38.410596
# 9     Gabra4  35.099338
# 10     Gria1  32.450331
# 11     P2rx7  27.152318
# 12     P2rx4  26.490066
# 13     Grid2  26.490066
# 14     Itpr1  25.165563
# 15     Asic2  24.503311
# 16     Grid1  24.503311
# 17    Grin3a  19.867550
# 18     Grik3  12.582781
# 19   Grid2ip  11.920530
# 20    Gabra5  11.258278
# 21     Itpr3  11.258278
# 22     Grik1  10.596026
# 23     Grik2   9.933775
# 24     Asic1   9.933775
# 25     Glra1   9.271523
# 26     Gabre   8.609272
# 27    Gabrb2   8.609272
# 28     Gria3   7.947020
# 29     Gabrq   7.947020
# 30    Gabrr2   7.284768
# 31    Gabrg3   7.284768
# 32     Grik4   7.284768
# 33    Gabra1   7.284768
# 34    Grin2a   7.284768
# 35     Grin1   6.622517
# 36    Chrnb2   6.622517
# 37     Htr3b   6.622517
# 38    Grin3b   6.622517
# 39     P2rx1   6.622517
# 40    Chrna2   6.622517
# 41     Gria4   5.960265
# 42    Chrnb1   5.960265
# 43     P2rx6   5.960265
# 44     P2rx3   5.298013
# 45    Chrna4   5.298013
# 46    Chrnb3   5.298013
# 47     Glra3   5.298013
# 48    Gabrg2   5.298013
# 49    Scnn1a   4.635762
# 50    Grin2d   4.635762

# %%
sc.pl.violin(adata_w, top_lgig, stripplot = True, jitter = 0.4, rotation = 90, save = 'Vmat2_violin_lgic_input.pdf')
# Out:
# WARNING: saving figure to file figures\violinVmat2_violin_lgic_input.pdf

# %%
percent_gpcr = pd.DataFrame(percentage_exp(adata_w, gpcr_list), columns = ['gene_name', 'percent'])
print(percent_gpcr[:51])
top_gpcr = percent_gpcr['gene_name'][:41]
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\anndata\core\anndata.py:846: FutureWarning: In anndata v0.7+, arrays contained within an AnnData object will maintain their dimensionality. For example, prior to v0.7 `adata[0, 0].X` returned a scalar and `adata[0, :]` returned a 1d array, post v0.7 they will return two dimensional arrays. If you would like to get a one dimensional array from your AnnData object, consider using the `adata.obs_vector`, `adata.var_vector` methods or accessing the array directly.
#   warn_flatten()
#     gene_name    percent
# 0       Ntsr2  98.675497
# 1     Gpr37l1  98.013245
# 2       S1pr1  98.013245
# 3        Grm3  93.377483
# 4      Gabbr1  87.417219
# 5       Ednrb  84.768212
# 6        Smox  80.132450
# 7        Fzd2  79.470199
# 8   Adcyap1r1  76.821192
# 9        Rhoa  73.509934
# 10     Gprc5b  69.536424
# 11       Lgr4  68.211921
# 12     Gpr146  68.211921
# 13       Rhob  67.549669
# 14     Celsr2  63.576159
# 15      Rhot1  60.927152
# 16     Gpr162  56.953642
# 17       Lgr6  56.291391
# 18       Rhoq  54.966887
# 19      Gpr19  52.317881
# 20      Gpr37  51.655629
# 21       Rhou  49.668874
# 22       Hrh1  47.682119
# 23     Gpr107  46.357616
# 24       Fzd1  46.357616
# 25    Rhobtb2  45.033113
# 26    Adora2b  41.059603
# 27     Celsr1  40.397351
# 28       Fzd9  36.423841
# 29     Adora1  35.761589
# 30     Gabbr2  35.761589
# 31     Gpr108  33.112583
# 32      Tpra1  32.450331
# 33     Gpr155  31.788079
# 34    Rhobtb3  31.125828
# 35     Gpr137  31.125828
# 36      Lpar6  29.139073
# 37       Rhoc  28.476821
# 38      Rhot2  27.152318
# 39       Rhog  25.165563
# 40      Ackr3  24.503311
# 41     Gpr123  23.841060
# 42     Gpr180  23.841060
# 43        Smo  23.178808
# 44      Ednra  23.178808
# 45      Adrb1  23.178808
# 46     Adra1b  21.854305
# 47     Adra1a  21.854305
# 48       Fzd3  19.867550
# 49     P2ry12  19.205298
# 50     Gpr156  18.543046

# %%
sc.pl.violin(adata_w, top_gpcr, stripplot= True, jitter = 0.4, rotation = 90, fig_size = (10,20), save = 'vmat2_violin_gpcr_input.pdf')
#sns.set(font_scale = 0.9)
# Out:
# WARNING: saving figure to file figures\violinvmat2_violin_gpcr_input.pdf

# %%
# open the Zeisel et al dataset
adata_proj = sc.read_loom('l6_r3_telencephalon_projecting_neurons.loom', sparse = False)
adata_proj
# Out:
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# AnnData object with n_obs × n_vars = 28858 × 27998
#     obs: 'Age', 'AnalysisPool', 'AnalysisProject', 'Bucket', 'CellConc', 'Cell_Conc', 'ChipID', 'Class', 'ClassProbability_Astrocyte', 'ClassProbability_Astrocyte,Immune', 'ClassProbability_Astrocyte,Neurons', 'ClassProbability_Astrocyte,Oligos', 'ClassProbability_Astrocyte,Vascular', 'ClassProbability_Bergmann-glia', 'ClassProbability_Blood', 'ClassProbability_Blood,Vascular', 'ClassProbability_Enteric-glia', 'ClassProbability_Enteric-glia,Cycling', 'ClassProbability_Ependymal', 'ClassProbability_Ex-Neurons', 'ClassProbability_Ex-Vascular', 'ClassProbability_Immune', 'ClassProbability_Immune,Neurons', 'ClassProbability_Immune,Oligos', 'ClassProbability_Neurons', 'ClassProbability_Neurons,Cycling', 'ClassProbability_Neurons,Oligos', 'ClassProbability_Neurons,Satellite-glia', 'ClassProbability_Neurons,Vascular', 'ClassProbability_OEC', 'ClassProbability_Oligos', 'ClassProbability_Oligos,Cycling', 'ClassProbability_Oligos,Vascular', 'ClassProbability_Satellite-glia', 'ClassProbability_Satellite-glia,Cycling', 'ClassProbability_Satellite-glia,Schwann', 'ClassProbability_Schwann', 'ClassProbability_Ttr', 'ClassProbability_Vascular', 'ClusterName', 'Clusters', 'Comment', 'Comments', 'DateCaptured', 'Date_Captured', 'Description', 'Developmental_compartment', 'DonorID', 'Estimated Number of Cells', 'Flowcell', 'Fraction Reads in Cells', 'Label', 'LeafOrder', 'Location_based_on', 'Mean Reads per Cell', 'Median Genes per Cell', 'Median UMI Counts per Cell', 'MitoRiboRatio', 'NGI_PlateWell', 'Neurotransmitter', 'NumPooledAnimals', 'Num_Pooled_Animals', 'Number of Reads', 'OriginalClusters', 'Outliers', 'PCRCycles', 'PCR_Cycles', 'PassedQC', 'PlugDate', 'Plug_Date', 'Probable_location', 'Project', 'Q30 Bases in Barcode', 'Q30 Bases in RNA Read', 'Q30 Bases in Sample Index', 'Q30 Bases in UMI', 'Reads Mapped Confidently to Exonic Regions', 'Reads Mapped Confidently to Intergenic Regions', 'Reads Mapped Confidently to Intronic Regions', 'Reads Mapped Confidently to Transcriptome', 'Region', 'SampleID', 'SampleIndex', 'SampleOK', 'Sample_Index', 'SeqComment', 'SeqLibDate', 'SeqLibOk', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Sequencing Saturation', 'Serial_Number', 'Sex', 'Species', 'Strain', 'Subclass', 'TargetNumCells', 'Target_Num_Cells', 'TaxonomyRank1', 'TaxonomyRank2', 'TaxonomyRank3', 'TaxonomyRank4', 'TaxonomySymbol', 'Taxonomy_group', 'TimepointPool', 'Tissue', 'Total Genes Detected', 'Transcriptome', 'Valid Barcodes', '_KMeans_10', '_LogCV', '_LogMean', '_NGenes', '_PC1', '_PC2', '_Total', '_Valid', '_X', '_Y', '_tSNE1', '_tSNE2', 'cDNAConcNanogramPerMicroliter', 'cDNALibOk', 'cDNA_Lib_Ok', 'ngperul_cDNA'
#     var: 'Accession', '_LogCV', '_LogMean', '_Selected', '_Total', '_Valid'

# %%
print(calc_celltype_observation(adata_proj, 'Probable_location'))
# Out:
#                                                     number_cells
# obs_name
# Anterior olfactory nucleus and ventral striatum               89
# Anterior olfactory nucleus, deep layer                       657
# Basolateral amygdala                                         958
# CA1                                                         2037
# CA1 (posterior),subiculum,entorhinal                         104
# CA3                                                          484
# Cingulate/Retrosplenial area, layer 2                        598
# Cingulate/Retrosplenial area, layer 5                        202
# Cingulate/Retrosplenial area, layer 6                        402
# Cortex pyramidal layer 5, Cingulate/Retrospleni...           664
# Cortex pyramidal layer 6                                    2789
# Cortex pyramidal layer 6b                                    274
# Cortical pyramidal (poor markers)                           1464
# Cortical pyramidal layer 2/3                                2435
# Cortical pyramidal layer 4                                  3071
# Cortical pyramidal layer 5                                   866
# Dentate gyrus                                               4368
# Entorhinal superficial layers                                126
# Lateral cortex layer 6: gustatory, barrel field...           386
# Piriform pyramidal                                          1031
# Striatum dorsal                                             1963
# Striatum ventral                                            3728
# Subiculum                                                    162

# %%
adata_cortex = adata_proj[adata_proj.obs['Region'] == 'Cortex']
adata_cortex
# Out:
# View of AnnData object with n_obs × n_vars = 15216 × 27998
#     obs: 'Age', 'AnalysisPool', 'AnalysisProject', 'Bucket', 'CellConc', 'Cell_Conc', 'ChipID', 'Class', 'ClassProbability_Astrocyte', 'ClassProbability_Astrocyte,Immune', 'ClassProbability_Astrocyte,Neurons', 'ClassProbability_Astrocyte,Oligos', 'ClassProbability_Astrocyte,Vascular', 'ClassProbability_Bergmann-glia', 'ClassProbability_Blood', 'ClassProbability_Blood,Vascular', 'ClassProbability_Enteric-glia', 'ClassProbability_Enteric-glia,Cycling', 'ClassProbability_Ependymal', 'ClassProbability_Ex-Neurons', 'ClassProbability_Ex-Vascular', 'ClassProbability_Immune', 'ClassProbability_Immune,Neurons', 'ClassProbability_Immune,Oligos', 'ClassProbability_Neurons', 'ClassProbability_Neurons,Cycling', 'ClassProbability_Neurons,Oligos', 'ClassProbability_Neurons,Satellite-glia', 'ClassProbability_Neurons,Vascular', 'ClassProbability_OEC', 'ClassProbability_Oligos', 'ClassProbability_Oligos,Cycling', 'ClassProbability_Oligos,Vascular', 'ClassProbability_Satellite-glia', 'ClassProbability_Satellite-glia,Cycling', 'ClassProbability_Satellite-glia,Schwann', 'ClassProbability_Schwann', 'ClassProbability_Ttr', 'ClassProbability_Vascular', 'ClusterName', 'Clusters', 'Comment', 'Comments', 'DateCaptured', 'Date_Captured', 'Description', 'Developmental_compartment', 'DonorID', 'Estimated Number of Cells', 'Flowcell', 'Fraction Reads in Cells', 'Label', 'LeafOrder', 'Location_based_on', 'Mean Reads per Cell', 'Median Genes per Cell', 'Median UMI Counts per Cell', 'MitoRiboRatio', 'NGI_PlateWell', 'Neurotransmitter', 'NumPooledAnimals', 'Num_Pooled_Animals', 'Number of Reads', 'OriginalClusters', 'Outliers', 'PCRCycles', 'PCR_Cycles', 'PassedQC', 'PlugDate', 'Plug_Date', 'Probable_location', 'Project', 'Q30 Bases in Barcode', 'Q30 Bases in RNA Read', 'Q30 Bases in Sample Index', 'Q30 Bases in UMI', 'Reads Mapped Confidently to Exonic Regions', 'Reads Mapped Confidently to Intergenic Regions', 'Reads Mapped Confidently to Intronic Regions', 'Reads Mapped Confidently to Transcriptome', 'Region', 'SampleID', 'SampleIndex', 'SampleOK', 'Sample_Index', 'SeqComment', 'SeqLibDate', 'SeqLibOk', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Sequencing Saturation', 'Serial_Number', 'Sex', 'Species', 'Strain', 'Subclass', 'TargetNumCells', 'Target_Num_Cells', 'TaxonomyRank1', 'TaxonomyRank2', 'TaxonomyRank3', 'TaxonomyRank4', 'TaxonomySymbol', 'Taxonomy_group', 'TimepointPool', 'Tissue', 'Total Genes Detected', 'Transcriptome', 'Valid Barcodes', '_KMeans_10', '_LogCV', '_LogMean', '_NGenes', '_PC1', '_PC2', '_Total', '_Valid', '_X', '_Y', '_tSNE1', '_tSNE2', 'cDNAConcNanogramPerMicroliter', 'cDNALibOk', 'cDNA_Lib_Ok', 'ngperul_cDNA'
#     var: 'Accession', '_LogCV', '_LogMean', '_Selected', '_Total', '_Valid'

# %%
cor_pyr = [name for name in adata_cortex.obs['Probable_location'] if name.startswith('Cort')]
cor_pyr_exc_1 = [name for name in adata_cortex.obs['Probable_location'] if name.startswith(('Cortical pyramidal (poo', 'Cortex pyramidal layer 5, Cingul'))]
cor_pyr_exc_1

adata_cortex.obs['pyr_cell'] = adata_cortex.obs['Probable_location'].isin(cor_pyr).astype(str)
adata_c = adata_cortex[adata_cortex.obs['pyr_cell'] == 'True']

adata_c.obs['bad_cells'] = adata_c.obs['Probable_location'].isin(cor_pyr_exc_1).astype(str)
adata_z = adata_c[adata_c.obs['bad_cells'] == 'False']
# Out:
# Trying to set attribute `.obs` of view, making a copy.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Trying to set attribute `.obs` of view, making a copy.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
#mito = set(sc.queries.mitochondrial_genes("www.ensembl.org", 'mmusculus'))
adata_z.var['mito'] = [True if gene in mito else False for gene in adata_z.var_names]
adata_z.var['ERCC'] = [True if gene.startswith('ERCC-') else False for gene in adata_z.var_names]
# Out:
# Trying to set attribute `.var` of view, making a copy.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
sc.pp.calculate_qc_metrics(adata_z, qc_vars= ['mito', 'ERCC'], inplace=True)

# %%
sns.distplot(adata_z.obs['log1p_total_counts'])
f_count = adata_z.obs_vector('log1p_total_counts') > 7

# %%
sns.jointplot('pct_counts_mito', 'total_counts_mito', data=adata_z.obs, kind="hex")
f_mito = adata_z.obs_vector('total_counts_mito') < 200
f_mito_p = adata_z.obs_vector('pct_counts_mito') < 2.5

# %%
sns.jointplot('log1p_n_genes_by_counts', 'pct_counts_in_top_50_genes', data=adata_z.obs, kind="hex")
f_dist = adata_z.obs_vector('pct_counts_in_top_50_genes') < 40 # filter cells with distributed gene counts
f_capt = adata_z.obs_vector('log1p_n_genes_by_counts') > 6.0 # filter cells with broad gene capture

# %%
#f_count, f_dist, f_capt, f_mito
f3 = np.logical_and(f_count, f_dist)
f4 = np.logical_and(f_capt, f_mito)
f5 = np.logical_and(f3,f4)
print(adata_z.shape)
adata_z = adata_z[f5]
sc.pp.filter_genes(adata_z, min_cells=3)
print(adata_z.shape)
# Out:
# (9435, 27998)
# Trying to set attribute `.var` of view, making a copy.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# (9049, 17217)

# %%
sc.pp.normalize_per_cell(adata_z, counts_per_cell_after=np.median(np.apply_over_axes(np.sum, adata_z.X, axes=1)))
sc.pp.log1p(adata_z)
adata_z_s = sc.pp.scale(adata_z, copy = True)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
#merge the two datasets based on all genes. Genes not expressed in the other dataset, will be set as zero
adata_2 = adata_z.concatenate(adata_w, join= 'outer', batch_categories= ['Zeisel', 'Vmat2-cre'])
adata_2.X = np.nan_to_num(adata_2.X)

#make the observation names unique
adata_2.obs_names_make_unique()
adata_2.var_names_make_unique()
# Out:
# Making variable names unique for controlled concatenation.

# %%
sc.pp.pca(adata_2) # have to use this to get two dimensions of the data
sc.pl.pca_scatter(adata_2, color= 'batch', save = 'Vmat2_zeisel_pca_scatter_unprocc.pdf')

#make the observation names unique
adata_2.obs_names_make_unique()
adata_2.var_names_make_unique()
# Out:
# ... storing 'Age' as categorical
# ... storing 'AnalysisPool' as categorical
# ... storing 'AnalysisProject' as categorical
# ... storing 'Animal' as categorical
# ... storing 'Bucket' as categorical
# ... storing 'CellConc' as categorical
# ... storing 'Cell_Conc' as categorical
# ... storing 'ChipID' as categorical
# ... storing 'Class' as categorical
# ... storing 'ClusterName' as categorical
# ... storing 'Comment' as categorical
# ... storing 'Comments' as categorical
# ... storing 'Connection' as categorical
# ... storing 'DateCaptured' as categorical
# ... storing 'Date_Captured' as categorical
# ... storing 'Description' as categorical
# ... storing 'Developmental_compartment' as categorical
# ... storing 'DonorID' as categorical
# ... storing 'Estimated Number of Cells' as categorical
# ... storing 'Experiment' as categorical
# ... storing 'Flowcell' as categorical
# ... storing 'Fraction Reads in Cells' as categorical
# ... storing 'Label' as categorical
# ... storing 'Location_based_on' as categorical
# ... storing 'Mean Reads per Cell' as categorical
# ... storing 'Median Genes per Cell' as categorical
# ... storing 'Median UMI Counts per Cell' as categorical
# ... storing 'NGI_PlateWell' as categorical
# ... storing 'Neurotransmitter' as categorical
# ... storing 'NumPooledAnimals' as categorical
# ... storing 'Num_Pooled_Animals' as categorical
# ... storing 'Number of Reads' as categorical
# ... storing 'PCRCycles' as categorical
# ... storing 'PCR_Cycles' as categorical
# ... storing 'PassedQC' as categorical
# ... storing 'PlugDate' as categorical
# ... storing 'Plug_Date' as categorical
# ... storing 'Probable_location' as categorical
# ... storing 'Project' as categorical
# ... storing 'Q30 Bases in Barcode' as categorical
# ... storing 'Q30 Bases in RNA Read' as categorical
# ... storing 'Q30 Bases in Sample Index' as categorical
# ... storing 'Q30 Bases in UMI' as categorical
# ... storing 'Reads Mapped Confidently to Exonic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Intergenic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Intronic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Transcriptome' as categorical
# ... storing 'Region' as categorical
# ... storing 'SampleID' as categorical
# ... storing 'SampleIndex' as categorical
# ... storing 'SampleOK' as categorical
# ... storing 'Sample_Index' as categorical
# ... storing 'SeqComment' as categorical
# ... storing 'SeqLibDate' as categorical
# ... storing 'SeqLibOk' as categorical
# ... storing 'Seq_Comment' as categorical
# ... storing 'Seq_Lib_Date' as categorical
# ... storing 'Seq_Lib_Ok' as categorical
# ... storing 'Sequencing Saturation' as categorical
# ... storing 'Serial_Number' as categorical
# ... storing 'Sex' as categorical
# ... storing 'Species' as categorical
# ... storing 'Strain' as categorical
# ... storing 'Subclass' as categorical
# ... storing 'TargetNumCells' as categorical
# ... storing 'Target_Num_Cells' as categorical
# ... storing 'TaxonomyRank1' as categorical
# ... storing 'TaxonomyRank2' as categorical
# ... storing 'TaxonomyRank3' as categorical
# ... storing 'TaxonomyRank4' as categorical
# ... storing 'TaxonomySymbol' as categorical
# ... storing 'Taxonomy_group' as categorical
# ... storing 'TimepointPool' as categorical
# ... storing 'Tissue' as categorical
# ... storing 'Total Genes Detected' as categorical
# ... storing 'Transcriptome' as categorical
# ... storing 'Valid Barcodes' as categorical
# ... storing 'bad_cells' as categorical
# ... storing 'cDNAConcNanogramPerMicroliter' as categorical
# ... storing 'cDNALibOk' as categorical
# ... storing 'cDNA_Lib_Ok' as categorical
# ... storing 'leiden' as categorical
# ... storing 'ngperul_cDNA' as categorical
# ... storing 'pyr_cell' as categorical
# ... storing 'Accession-Zeisel' as categorical
# ... storing 'mito-Zeisel' as categorical
# ... storing 'ERCC-Zeisel' as categorical
# ... storing 'ERCC-Vmat2-cre' as categorical
# ... storing 'mito-Vmat2-cre' as categorical
# ... storing 'highly_variable-Vmat2-cre' as categorical
# WARNING: saving figure to file figures\pcaVmat2_zeisel_pca_scatter_unprocc.pdf

# %%
#adata_z_norm = adata[adata.obs['batch'] == 'Zeisel']
sc.pp.highly_variable_genes(adata_z, n_top_genes=5000)
#adata_z_h = adata_z_norm[:, adata_z_norm.var['highly_variable']]

#adata_h_norm = adata[adata.obs['batch'] == 'Haring']
sc.pp.highly_variable_genes(adata_w, n_top_genes=5000)
#adata_h_h = adata_h_norm[:, adata_h_norm.var['highly_variable']]

joined_adata = adata_w.concatenate(adata_z, join = 'inner', batch_categories= ['Vmat2-Cre', 'Zeisel'])
joined_HVG = list(joined_adata.var_names)

# %%
adata_z_s = sc.pp.scale(adata_z, copy = True)
adata_w_s = sc.pp.scale(adata_w, copy = True)

# %%
adata_corr_2 = (sc.external.pp.mnn_correct(adata_z_s[:, joined_HVG], adata_w_s[:, joined_HVG], batch_categories = ['Zeisel', 'Vmat2-Cre'], do_concatenate= True))[0]
adata_corr_2
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:14: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "l2_norm" failed type inference due to: Invalid use of Function(<function norm at 0x000001EDC543A158>) with argument(s) of type(s): (axis=Literal[int](1), x=array(float32, 2d, A))
#  * parameterized
# In definition 0:
#     TypeError: norm_impl() got an unexpected keyword argument 'x'
#     raised from C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\typing\templates.py:475
# In definition 1:
#     TypeError: norm_impl() got an unexpected keyword argument 'x'
#     raised from C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\typing\templates.py:475
# This error is usually caused by passing an argument of a type that is unsupported by the named function.
# [1] During: resolving callee type: Function(<function norm at 0x000001EDC543A158>)
# [2] During: typing of call at C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py (16)
#
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 16:
# def l2_norm(in_matrix):
#     return np.linalg.norm(x=in_matrix, axis=1)
#     ^
#
#   @jit(float32[:](float32[:, :]), nogil=True)
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:742: NumbaWarning: Function "l2_norm" was compiled in object mode without forceobj=True.
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 15:
# @jit(float32[:](float32[:, :]), nogil=True)
# def l2_norm(in_matrix):
# ^
#
#   self.func_ir.loc))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:751: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 15:
# @jit(float32[:](float32[:, :]), nogil=True)
# def l2_norm(in_matrix):
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, self.func_ir.loc))
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:14: NumbaWarning: Code running in object mode won't allow parallel execution despite nogil=True.
#   @jit(float32[:](float32[:, :]), nogil=True)
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:29: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float32, 1d, A), array(float32, 1d, A))
#   dist[i, j] = np.dot(m[i], n[j])
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:88: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "find_mutual_nn" failed type inference due to: Untyped global name 'cKDTree': cannot determine Numba type of <class 'type'>
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 90:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     k_index_1 = cKDTree(data1).query(x=data2, k=k1, n_jobs=n_jobs)[1]
#     ^
#
#   @jit((float32[:, :], float32[:, :], int8, int8, int8))
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:88: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "find_mutual_nn" failed type inference due to: Untyped global name 'cKDTree': cannot determine Numba type of <class 'type'>
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 90:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     k_index_1 = cKDTree(data1).query(x=data2, k=k1, n_jobs=n_jobs)[1]
#     ^
#
#   @jit((float32[:, :], float32[:, :], int8, int8, int8))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:742: NumbaWarning: Function "find_mutual_nn" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 89:
# @jit((float32[:, :], float32[:, :], int8, int8, int8))
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
# ^
#
#   self.func_ir.loc))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:751: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 89:
# @jit((float32[:, :], float32[:, :], int8, int8, int8))
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, self.func_ir.loc))
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:102: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "compute_correction" failed type inference due to: Invalid use of Function(<function unique at 0x000001EDC54B2C80>) with argument(s) of type(s): (array(int32, 1d, A), return_counts=bool)
#  * parameterized
# In definition 0:
#     TypeError: np_unique() got an unexpected keyword argument 'return_counts'
#     raised from C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\typing\templates.py:475
# In definition 1:
#     TypeError: np_unique() got an unexpected keyword argument 'return_counts'
#     raised from C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\typing\templates.py:475
# This error is usually caused by passing an argument of a type that is unsupported by the named function.
# [1] During: resolving callee type: Function(<function unique at 0x000001EDC54B2C80>)
# [2] During: typing of call at C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py (105)
#
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 105:
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
#     <source elided>
#     vect = data1[mnn1] - data2[mnn2]
#     mnn_index, mnn_count = np.unique(mnn2, return_counts=True)
#     ^
#
#   @jit(float32[:, :](float32[:, :], float32[:, :], int32[:], int32[:], float32[:, :], float32))
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:102: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "compute_correction" failed type inference due to: cannot determine Numba type of <class 'numba.dispatcher.LiftedLoop'>
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 107:
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
#     <source elided>
#     vect_reduced = np.zeros((data2.shape[0], vect.shape[1]), dtype=np.float32)
#     for index, ve in zip(mnn2, vect):
#     ^
#
#   @jit(float32[:, :](float32[:, :], float32[:, :], int32[:], int32[:], float32[:, :], float32))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:742: NumbaWarning: Function "compute_correction" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 103:
# @jit(float32[:, :](float32[:, :], float32[:, :], int32[:], int32[:], float32[:, :], float32))
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
# ^
#
#   self.func_ir.loc))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:751: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 103:
# @jit(float32[:, :](float32[:, :], float32[:, :], int32[:], int32[:], float32[:, :], float32))
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, self.func_ir.loc))
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:199: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "adjust_s_variance" failed type inference due to: Untyped global name 'sq_dist_to_line': cannot determine Numba type of <class 'numba.ir.UndefinedType'>
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 209:
# def adjust_s_variance(data1, data2, curcell, curvect, sigma):
#     <source elided>
#         sameproj = np.dot(grad, samecell)
#         samedist = sq_dist_to_line(curcell, grad, samecell)
#         ^
#
#   @jit(float32(float32[:, :], float32[:, :], float32[:], float32[:], float32), nogil=True)
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:199: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "adjust_s_variance" failed type inference due to: cannot determine Numba type of <class 'numba.dispatcher.LiftedLoop'>
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 207:
# def adjust_s_variance(data1, data2, curcell, curvect, sigma):
#     <source elided>
#     totalprob2 = 0.
#     for samecell in data2:
#     ^
#
#   @jit(float32(float32[:, :], float32[:, :], float32[:], float32[:], float32), nogil=True)
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:742: NumbaWarning: Function "adjust_s_variance" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 200:
# @jit(float32(float32[:, :], float32[:, :], float32[:], float32[:], float32), nogil=True)
# def adjust_s_variance(data1, data2, curcell, curvect, sigma):
# ^
#
#   self.func_ir.loc))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:751: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 200:
# @jit(float32(float32[:, :], float32[:, :], float32[:], float32[:], float32), nogil=True)
# def adjust_s_variance(data1, data2, curcell, curvect, sigma):
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, self.func_ir.loc))
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:199: NumbaWarning: Code running in object mode won't allow parallel execution despite nogil=True.
#   @jit(float32(float32[:, :], float32[:, :], float32[:], float32[:], float32), nogil=True)
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:238: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float32, 1d, C), array(float32, 1d, A))
#   scale = np.dot(working, grad)
# Performing cosine normalization...
# Starting MNN correct iteration. Reference batch: 0
# Step 1 of 1: processing batch 1
#   Looking for MNNs...
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:88: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "find_mutual_nn" failed type inference due to: non-precise type pyobject
# [1] During: typing of argument at C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py (94)
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 94:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     <source elided>
#     mutual_2 = []
#     for index_2 in range(data2.shape[0]):
#     ^
#
#   @jit((float32[:, :], float32[:, :], int8, int8, int8))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:742: NumbaWarning: Function "find_mutual_nn" was compiled in object mode without forceobj=True.
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 94:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     <source elided>
#     mutual_2 = []
#     for index_2 in range(data2.shape[0]):
#     ^
#
#   self.func_ir.loc))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:751: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 94:
# def find_mutual_nn(data1, data2, k1, k2, n_jobs):
#     <source elided>
#     mutual_2 = []
#     for index_2 in range(data2.shape[0]):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, self.func_ir.loc))
#   Computing correction vectors...
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\ir_utils.py:1959: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'mnn2' of function 'compute_correction'.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 107:
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
#     <source elided>
#     vect_reduced = np.zeros((data2.shape[0], vect.shape[1]), dtype=np.float32)
#     for index, ve in zip(mnn2, vect):
#     ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py:102: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function compute_correction failed at nopython mode lowering due to: iterating over 2D array
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 107:
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
#     <source elided>
#     vect_reduced = np.zeros((data2.shape[0], vect.shape[1]), dtype=np.float32)
#     for index, ve in zip(mnn2, vect):
#     ^
#
# [1] During: lowering "$78.2 = iternext(value=$phi78.1)" at C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py (107)
#   @jit(float32[:, :](float32[:, :], float32[:, :], int32[:], int32[:], float32[:, :], float32))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:742: NumbaWarning: Function "compute_correction" was compiled in object mode without forceobj=True.
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 107:
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
#     <source elided>
#     vect_reduced = np.zeros((data2.shape[0], vect.shape[1]), dtype=np.float32)
#     for index, ve in zip(mnn2, vect):
#     ^
#
#   self.func_ir.loc))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:751: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\mnnpy\utils.py", line 107:
# def compute_correction(data1, data2, mnn1, mnn2, data2_or_raw2, sigma):
#     <source elided>
#     vect_reduced = np.zeros((data2.shape[0], vect.shape[1]), dtype=np.float32)
#     for index, ve in zip(mnn2, vect):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, self.func_ir.loc))
#   Adjusting variance...
#   Applying correction...
# MNN correction complete. Gathering output...
# Packing AnnData object...
# Done.
# AnnData object with n_obs × n_vars = 9200 × 14399
#     obs: 'Age', 'AnalysisPool', 'AnalysisProject', 'Animal', 'Bucket', 'CellConc', 'Cell_Conc', 'ChipID', 'Class', 'ClassProbability_Astrocyte', 'ClassProbability_Astrocyte,Immune', 'ClassProbability_Astrocyte,Neurons', 'ClassProbability_Astrocyte,Oligos', 'ClassProbability_Astrocyte,Vascular', 'ClassProbability_Bergmann-glia', 'ClassProbability_Blood', 'ClassProbability_Blood,Vascular', 'ClassProbability_Enteric-glia', 'ClassProbability_Enteric-glia,Cycling', 'ClassProbability_Ependymal', 'ClassProbability_Ex-Neurons', 'ClassProbability_Ex-Vascular', 'ClassProbability_Immune', 'ClassProbability_Immune,Neurons', 'ClassProbability_Immune,Oligos', 'ClassProbability_Neurons', 'ClassProbability_Neurons,Cycling', 'ClassProbability_Neurons,Oligos', 'ClassProbability_Neurons,Satellite-glia', 'ClassProbability_Neurons,Vascular', 'ClassProbability_OEC', 'ClassProbability_Oligos', 'ClassProbability_Oligos,Cycling', 'ClassProbability_Oligos,Vascular', 'ClassProbability_Satellite-glia', 'ClassProbability_Satellite-glia,Cycling', 'ClassProbability_Satellite-glia,Schwann', 'ClassProbability_Schwann', 'ClassProbability_Ttr', 'ClassProbability_Vascular', 'ClusterName', 'Clusters', 'Comment', 'Comments', 'Connection', 'DateCaptured', 'Date_Captured', 'Description', 'Developmental_compartment', 'DonorID', 'Estimated Number of Cells', 'Experiment', 'Flowcell', 'Fraction Reads in Cells', 'Label', 'LeafOrder', 'Location_based_on', 'Mean Reads per Cell', 'Median Genes per Cell', 'Median UMI Counts per Cell', 'MitoRiboRatio', 'NGI_PlateWell', 'Neurotransmitter', 'NumPooledAnimals', 'Num_Pooled_Animals', 'Number of Reads', 'OriginalClusters', 'Outliers', 'PCRCycles', 'PCR_Cycles', 'PassedQC', 'PlugDate', 'Plug_Date', 'Probable_location', 'Project', 'Q30 Bases in Barcode', 'Q30 Bases in RNA Read', 'Q30 Bases in Sample Index', 'Q30 Bases in UMI', 'Reads Mapped Confidently to Exonic Regions', 'Reads Mapped Confidently to Intergenic Regions', 'Reads Mapped Confidently to Intronic Regions', 'Reads Mapped Confidently to Transcriptome', 'Region', 'SampleID', 'SampleIndex', 'SampleOK', 'Sample_Index', 'SeqComment', 'SeqLibDate', 'SeqLibOk', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Sequencing Saturation', 'Serial_Number', 'Sex', 'Species', 'Strain', 'Subclass', 'TargetNumCells', 'Target_Num_Cells', 'TaxonomyRank1', 'TaxonomyRank2', 'TaxonomyRank3', 'TaxonomyRank4', 'TaxonomySymbol', 'Taxonomy_group', 'TimepointPool', 'Tissue', 'Total Genes Detected', 'Transcriptome', 'Valid Barcodes', '_KMeans_10', '_LogCV', '_LogMean', '_NGenes', '_PC1', '_PC2', '_Total', '_Valid', '_X', '_Y', '_tSNE1', '_tSNE2', 'bad_cells', 'batch', 'cDNAConcNanogramPerMicroliter', 'cDNALibOk', 'cDNA_Lib_Ok', 'leiden', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_ERCC', 'log1p_total_counts_mito', 'n_counts', 'n_genes_by_counts', 'ngperul_cDNA', 'pct_counts_ERCC', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'pct_counts_in_top_50_genes', 'pct_counts_mito', 'pyr_cell', 'total_counts', 'total_counts_ERCC', 'total_counts_mito'
#     var: 'Accession-Zeisel', '_LogCV-Zeisel', '_LogMean-Zeisel', '_Selected-Zeisel', '_Total-Zeisel', '_Valid-Zeisel', 'mito', 'ERCC', 'n_cells_by_counts-Zeisel', 'mean_counts-Zeisel', 'log1p_mean_counts-Zeisel', 'pct_dropout_by_counts-Zeisel', 'total_counts-Zeisel', 'log1p_total_counts-Zeisel', 'n_cells-Zeisel', 'highly_variable-Zeisel', 'means-Zeisel', 'dispersions-Zeisel', 'dispersions_norm-Zeisel', 'n_cells_by_counts-Vmat2-Cre', 'mean_counts-Vmat2-Cre', 'log1p_mean_counts-Vmat2-Cre', 'pct_dropout_by_counts-Vmat2-Cre', 'total_counts-Vmat2-Cre', 'log1p_total_counts-Vmat2-Cre', 'n_cells-Vmat2-Cre', 'highly_variable-Vmat2-Cre', 'means-Vmat2-Cre', 'dispersions-Vmat2-Cre', 'dispersions_norm-Vmat2-Cre'

# %%
sc.pp.pca(adata_corr_2)
sc.pl.pca_overview(adata_corr_2)
# Out:
# ... storing 'Age' as categorical
# ... storing 'AnalysisPool' as categorical
# ... storing 'AnalysisProject' as categorical
# ... storing 'Animal' as categorical
# ... storing 'Bucket' as categorical
# ... storing 'CellConc' as categorical
# ... storing 'Cell_Conc' as categorical
# ... storing 'ChipID' as categorical
# ... storing 'Class' as categorical
# ... storing 'ClusterName' as categorical
# ... storing 'Comment' as categorical
# ... storing 'Comments' as categorical
# ... storing 'Connection' as categorical
# ... storing 'DateCaptured' as categorical
# ... storing 'Date_Captured' as categorical
# ... storing 'Description' as categorical
# ... storing 'Developmental_compartment' as categorical
# ... storing 'DonorID' as categorical
# ... storing 'Estimated Number of Cells' as categorical
# ... storing 'Experiment' as categorical
# ... storing 'Flowcell' as categorical
# ... storing 'Fraction Reads in Cells' as categorical
# ... storing 'Label' as categorical
# ... storing 'Location_based_on' as categorical
# ... storing 'Mean Reads per Cell' as categorical
# ... storing 'Median Genes per Cell' as categorical
# ... storing 'Median UMI Counts per Cell' as categorical
# ... storing 'NGI_PlateWell' as categorical
# ... storing 'Neurotransmitter' as categorical
# ... storing 'NumPooledAnimals' as categorical
# ... storing 'Num_Pooled_Animals' as categorical
# ... storing 'Number of Reads' as categorical
# ... storing 'PCRCycles' as categorical
# ... storing 'PCR_Cycles' as categorical
# ... storing 'PassedQC' as categorical
# ... storing 'PlugDate' as categorical
# ... storing 'Plug_Date' as categorical
# ... storing 'Probable_location' as categorical
# ... storing 'Project' as categorical
# ... storing 'Q30 Bases in Barcode' as categorical
# ... storing 'Q30 Bases in RNA Read' as categorical
# ... storing 'Q30 Bases in Sample Index' as categorical
# ... storing 'Q30 Bases in UMI' as categorical
# ... storing 'Reads Mapped Confidently to Exonic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Intergenic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Intronic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Transcriptome' as categorical
# ... storing 'Region' as categorical
# ... storing 'SampleID' as categorical
# ... storing 'SampleIndex' as categorical
# ... storing 'SampleOK' as categorical
# ... storing 'Sample_Index' as categorical
# ... storing 'SeqComment' as categorical
# ... storing 'SeqLibDate' as categorical
# ... storing 'SeqLibOk' as categorical
# ... storing 'Seq_Comment' as categorical
# ... storing 'Seq_Lib_Date' as categorical
# ... storing 'Seq_Lib_Ok' as categorical
# ... storing 'Sequencing Saturation' as categorical
# ... storing 'Serial_Number' as categorical
# ... storing 'Sex' as categorical
# ... storing 'Species' as categorical
# ... storing 'Strain' as categorical
# ... storing 'Subclass' as categorical
# ... storing 'TargetNumCells' as categorical
# ... storing 'Target_Num_Cells' as categorical
# ... storing 'TaxonomyRank1' as categorical
# ... storing 'TaxonomyRank2' as categorical
# ... storing 'TaxonomyRank3' as categorical
# ... storing 'TaxonomyRank4' as categorical
# ... storing 'TaxonomySymbol' as categorical
# ... storing 'Taxonomy_group' as categorical
# ... storing 'TimepointPool' as categorical
# ... storing 'Tissue' as categorical
# ... storing 'Total Genes Detected' as categorical
# ... storing 'Transcriptome' as categorical
# ... storing 'Valid Barcodes' as categorical
# ... storing 'bad_cells' as categorical
# ... storing 'cDNAConcNanogramPerMicroliter' as categorical
# ... storing 'cDNALibOk' as categorical
# ... storing 'cDNA_Lib_Ok' as categorical
# ... storing 'leiden' as categorical
# ... storing 'ngperul_cDNA' as categorical
# ... storing 'pyr_cell' as categorical

# %%
sc.pp.neighbors(adata_corr_2, n_neighbors= 10, n_pcs= 9)
sc.tl.umap(adata_corr_2)
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\rp_tree.py:439: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "make_euclidean_tree" failed type inference due to: Invalid use of recursive(type(CPUDispatcher(<function make_euclidean_tree at 0x000001EDCE268730>))) with parameters (array(float32, 2d, A), array(int64, 1d, C), array(int64, 1d, C), int64)
# No type info available for recursive(type(CPUDispatcher(<function make_euclidean_tree at 0x000001EDCE268730>))) as a callable.
# [1] During: resolving callee type: recursive(type(CPUDispatcher(<function make_euclidean_tree at 0x000001EDCE268730>)))
# [2] During: typing of call at C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\rp_tree.py (446)
#
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\rp_tree.py", line 446:
# def make_euclidean_tree(data, indices, rng_state, leaf_size=30):
#     <source elided>
#
#         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
#         ^
#
#   @numba.jit()
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:742: NumbaWarning: Function "make_euclidean_tree" was compiled in object mode without forceobj=True.
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\rp_tree.py", line 440:
# @numba.jit()
# def make_euclidean_tree(data, indices, rng_state, leaf_size=30):
# ^
#
#   self.func_ir.loc))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:751: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\rp_tree.py", line 440:
# @numba.jit()
# def make_euclidean_tree(data, indices, rng_state, leaf_size=30):
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, self.func_ir.loc))
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\nndescent.py:92: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\utils.py", line 407:
# @numba.njit(parallel=True)
# def build_candidates(current_graph, n_vertices, n_neighbors, max_candidates, rng_state):
# ^
#
#   current_graph, n_vertices, n_neighbors, max_candidates, rng_state
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\umap_.py:328: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "fuzzy_simplicial_set" failed type inference due to: Untyped global name 'nearest_neighbors': cannot determine Numba type of <class 'function'>
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\umap_.py", line 446:
# def fuzzy_simplicial_set(
#     <source elided>
#     if knn_indices is None or knn_dists is None:
#         knn_indices, knn_dists, _ = nearest_neighbors(
#         ^
#
#   @numba.jit()
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:742: NumbaWarning: Function "fuzzy_simplicial_set" was compiled in object mode without forceobj=True.
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\umap_.py", line 329:
# @numba.jit()
# def fuzzy_simplicial_set(
# ^
#
#   self.func_ir.loc))
# C:\Users\hanwe868\AppData\Roaming\Python\Python36\site-packages\numba\compiler.py:751: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\..\..\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\umap_.py", line 329:
# @numba.jit()
# def fuzzy_simplicial_set(
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, self.func_ir.loc))

# %%
sc.pl.umap(adata_corr_2, color = 'batch',save = 'umap_zeisel_Vmat2_procc.pdf')
# Out:
# WARNING: saving figure to file figures\umapumap_zeisel_Vmat2_procc.pdf

# %%
sc.pl.umap(adata_corr_2, color = 'Probable_location',save = 'umap_zeisel_Vmat2_loc_procc.pdf')
#make the observation names unique
adata_corr_2.obs_names_make_unique()
adata_corr_2.var_names_make_unique()
# Out:
# WARNING: saving figure to file figures\umapumap_zeisel_Vmat2_loc_procc.pdf

# %%
def calc_celltype_observation(adata, observation):
    pd_adata = pd.DataFrame(index = adata.obs_names, columns = adata.var_names, data = adata.X)
    pd_adata['obs_name'] = adata.obs[observation]
    pd_celltype = pd.DataFrame(pd_adata.loc[pd_adata.index, 'obs_name'])
    pd_celltype = pd.DataFrame(pd_adata.groupby('obs_name').size(), columns = ['number_cells'])
    return(pd_celltype)

# %%
print(calc_celltype_observation(adata_corr_2, 'Probable_location'))
# Out:
#                               number_cells
# obs_name
# Cortex pyramidal layer 6              2745
# Cortex pyramidal layer 6b              258
# Cortical pyramidal layer 2/3          2368
# Cortical pyramidal layer 4            2963
# Cortical pyramidal layer 5             715
# nan                                    151

# %%
# create testing datasets
train_X = adata_corr_2.X[adata_corr_2.obs["batch"] == "Zeisel", :]
train_y = adata_corr_2.obs["Probable_location"][adata_corr_2.obs["batch"] == "Zeisel"].values
test_X = adata_corr_2.X[adata_corr_2.obs["batch"] == "Vmat2-Cre", :]

# %% [markdown]
# from sklearn import linear_model
# from sklearn.svm import LinearSVC
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.linear_model import LogisticRegression
#
# #evaluating linear SGDClassifier
# model_sgd = linear_model.SGDClassifier(max_iter=1000, tol=1e-3)
# model_sgd.fit(train_X, train_y)
# print('SDGClassifier:', (model_sgd.score(train_X, train_y)))
#
# #evaluating linearSVC
# model_lsv = LinearSVC(dual=False)
# model_lsv.fit(train_X, train_y)
# print('LinearSVG:', (model_lsv.score(train_X, train_y)))
#
# #evaluating KNeigbors
# model_knn = KNeighborsClassifier(n_neighbors=5)
# model_knn.fit(train_X, train_y)
# print('KNeighborsClassifier:', (model_knn.score(train_X, train_y)))
#
# #evaluate logistic regression model
# model_lr = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial').fit(train_X, train_y)
# print('LogisticRegression:', (model_lr.score(train_X, train_y)))

# %%
from sklearn import linear_model
#evaluating linear SGDClassifier
model_sgd = linear_model.SGDClassifier(max_iter=1000, tol=1e-3, loss = 'log')
model_sgd.fit(train_X, train_y)
print('SDGClassifier:', (model_sgd.score(train_X, train_y)))
labels = model_sgd.predict(test_X)
prob = model_sgd.predict_proba(adata_corr_2.X)
# Out:
# SDGClassifier: 0.9813239031937231

# %%
prob = np.max(prob, axis = 1)

# %%
adata_corr_2.obs["Probable_location"][adata_corr_2.obs["batch"] == "Vmat2-Cre"] = labels
adata_corr_2.obs["probability"] = prob

# %%
adata_corr_2.obs['Probable_location']
# Out:
# 10X28_3_TATCCAACGTCAAC-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_2_CATTTCGATAGTCG-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_3_TGAATAACCCATGA-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_2_GCAGCGTGGGAACG-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_1_ATAGCCGACAGAAA-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_3_TCCTAAACCAGAAA-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_1_TGAGTCGAAACGAA-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_1_AAGACAGAGACAAA-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_2_TTCATGTGCTCGCT-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_2_ACCGTGCTCGACTA-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_3_TCGTTATGTGTTTC-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_2_CCTTTAGAGAGAGC-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_1_CCGTACACACTAGC-1-Zeisel    Cortical pyramidal layer 2/3
# 10X22_1_GTATCACTAGTGCT-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_2_AGTCGAACGTCACA-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_1_AAAGTTTGCTTCTA-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_2_ACCTCCGAGGTGGA-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_1_ACTTGGGACTCCAC-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_3_TATGAATGGGTAAA-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_3_ACAGTGTGCGCCTT-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_2_GCATGATGACCATG-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_3_TATCTTCTCTACTT-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_2_CGTTAGGAGACAGG-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_2_GCAGGGCTTCAGAC-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_2_TGATACCTCTCGCT-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_2_ACGTGATGGGTTAC-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_2_GATCGTGAGTCAAC-1-Zeisel    Cortical pyramidal layer 2/3
# 10X20_1_ACCCTCGAGGTCTA-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_2_TCATGTACAACCGT-1-Zeisel    Cortical pyramidal layer 2/3
# 10X28_2_ACATACCTACTGGT-1-Zeisel    Cortical pyramidal layer 2/3
#                                                ...
# O11-Vmat2-Cre                      Cortical pyramidal layer 2/3
# O10-Vmat2-Cre                      Cortical pyramidal layer 2/3
# O16-Vmat2-Cre                        Cortical pyramidal layer 4
# O13-Vmat2-Cre                      Cortical pyramidal layer 2/3
# O15-Vmat2-Cre                        Cortical pyramidal layer 4
# O20-Vmat2-Cre                      Cortical pyramidal layer 2/3
# O19-Vmat2-Cre                        Cortical pyramidal layer 4
# O22-Vmat2-Cre                      Cortical pyramidal layer 2/3
# O21-Vmat2-Cre                      Cortical pyramidal layer 2/3
# P4-Vmat2-Cre                           Cortex pyramidal layer 6
# P1-Vmat2-Cre                         Cortical pyramidal layer 4
# O23-Vmat2-Cre                      Cortical pyramidal layer 2/3
# P3-Vmat2-Cre                       Cortical pyramidal layer 2/3
# P6-Vmat2-Cre                         Cortical pyramidal layer 4
# P7-Vmat2-Cre                         Cortical pyramidal layer 4
# P5-Vmat2-Cre                         Cortical pyramidal layer 4
# P9-Vmat2-Cre                       Cortical pyramidal layer 2/3
# P16-Vmat2-Cre                        Cortical pyramidal layer 4
# P8-Vmat2-Cre                         Cortical pyramidal layer 4
# P17-Vmat2-Cre                      Cortical pyramidal layer 2/3
# P15-Vmat2-Cre                        Cortical pyramidal layer 4
# P13-Vmat2-Cre                      Cortical pyramidal layer 2/3
# P10-Vmat2-Cre                        Cortical pyramidal layer 4
# P11-Vmat2-Cre                      Cortical pyramidal layer 2/3
# P18-Vmat2-Cre                        Cortical pyramidal layer 4
# P14-Vmat2-Cre                        Cortical pyramidal layer 4
# P19-Vmat2-Cre                        Cortical pyramidal layer 4
# P22-Vmat2-Cre                        Cortical pyramidal layer 4
# P21-Vmat2-Cre                        Cortical pyramidal layer 4
# P20-Vmat2-Cre                        Cortical pyramidal layer 4
# Name: Probable_location, Length: 9200, dtype: category
# Categories (6, object): [Cortex pyramidal layer 6, Cortex pyramidal layer 6b, Cortical pyramidal layer 2/3, Cortical pyramidal layer 4, Cortical pyramidal layer 5, nan]

# %% [raw]
# adata_corr_2.obs['Probable_location_nan'] = (adata_corr_2.obs['Probable_location'] == 'nan').astype(str)
# adata_corr_2 = adata_corr_2[adata_corr_2.obs['Probable_location_nan'] == 'False']
# adata_corr_2

# %%
sc.pl.umap(adata_corr_2, color = 'Probable_location', save = 'umap_zeisel_vmat2_batch_anntotated_procc.pdf')
# Out:
# WARNING: saving figure to file figures\umapumap_zeisel_vmat2_batch_anntotated_procc.pdf

# %%
sc.pl.umap(adata_corr_2, color = 'probability', color_map = 'RdBu', save = 'umap_zeisel_vmat2_probability_procc.pdf')
# Out:
# WARNING: saving figure to file figures\umapumap_zeisel_vmat2_probability_procc.pdf

# %%
adata_f_2 = adata_corr_2[adata_corr_2.obs['batch'] == 'Vmat2-Cre']
distplot_prob_loc = sns.distplot(adata_f_2.obs['probability'])
plt.show()
fig = distplot_prob_loc.get_figure()
fig.savefig('distplot_prob_loc.pdf')

# %%
adata_w.obs_names = adata_f_2.obs_names
adata_w.obs_names

adata_w.obs['Probable_location'] = adata_f_2.obs['Probable_location']

# %%
sc.pl.umap(adata_w, color='Probable_location', save = 'umap_vmat2_annotated_locations.pdf')
# Out:
# WARNING: saving figure to file figures\umapumap_vmat2_annotated_locations.pdf

# %%
sc.tl.rank_genes_groups(adata_w, groupby = 'Probable_location')

# %%
sc.tl.dendrogram(adata_w, groupby= 'Probable_location')
sc.pl.rank_genes_groups_stacked_violin(adata_w, n_genes= 15, stripplot = True, jitter= 0.4, groupby = 'Probable_location', save = 'stacked_violin_ranked_genes_vmat2_location.pdf')
# Out:
# WARNING: saving figure to file figures\stacked_violinstacked_violin_ranked_genes_vmat2_location.pdf

# %%
result = adata_w.uns['rank_genes_groups']
groups = result['names'].dtype.names
pd.DataFrame({group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'scores', 'pvals_adj']}).head(40)
# Out:
#    Cortex pyramidal layer 6_n  Cortex pyramidal layer 6_s  \
# 0                      Pcsk1n                    4.114220
# 1                      Rps27l                    3.612239
# 2                         Cpe                    3.316373
# 3                        Pon2                    3.097529
# 4                        Etfa                    2.717981
# 5                       Usmg5                    2.685657
# 6                       Ap2m1                    2.576190
# 7                        Rrp1                    2.468914
# 8                        Fth1                    2.435648
# 9                     Sparcl1                    2.420703
    pd_adata = pd.DataFrame(index = adata.obs_names, columns = adata.var_names, data = adata.X)
    pd_adata['obs_name'] = adata.obs[observation]
    pd_celltype = pd.DataFrame(pd_adata.loc[pd_adata.index, 'obs_name'])
    pd_celltype = pd.DataFrame(pd_adata.groupby('obs_name').size(), columns = ['number_cells'])
    return(pd_celltype)

# %%
calc_Vmat = calc_celltype_observation(adata_f_2, 'Probable_location')
print(calc_Vmat)

print((calc_Vmat/len(adata_f_2.obs_names))*100)
# Out:
#                               number_cells
# obs_name
# Cortex pyramidal layer 6                 4
# Cortical pyramidal layer 2/3            47
# Cortical pyramidal layer 4             100
#                               number_cells
# obs_name
# Cortex pyramidal layer 6          2.649007
# Cortical pyramidal layer 2/3     31.125828
# Cortical pyramidal layer 4       66.225166

# %%
# create testing datasets
train_X_2 = adata_corr_2.X[adata_corr_2.obs["batch"] == "Zeisel", :]
train_y_2 = adata_corr_2.obs["ClusterName"][adata_corr_2.obs["batch"] == "Zeisel"].values
test_X_2 = adata_corr_2.X[adata_corr_2.obs["batch"] == "Vmat2-Cre", :]

# %%
from sklearn import linear_model
#evaluating linear SGDClassifier
model_sgd = linear_model.SGDClassifier(max_iter=1000, tol=1e-3, loss = 'log')
model_sgd.fit(train_X_2, train_y_2)
print('SDGClassifier:', (model_sgd.score(train_X_2, train_y_2)))
labels_2 = model_sgd.predict(test_X_2)
prob_2 = model_sgd.predict_proba(adata_corr_2.X)
# Out:
# SDGClassifier: 0.9804398276052603

# %%
prob_2 = np.max(prob_2, axis = 1)

# %%
adata_corr_2.obs["ClusterName"][adata_corr_2.obs["batch"] == "Vmat2-Cre"] = labels_2
adata_corr_2.obs["probability_2"] = prob_2

# %%
sc.pl.umap(adata_corr_2, color = 'probability_2', color_map = 'GnBu', save = 'umap_zeisel_vmat2_probability_cluster.pdf')
# Out:
# WARNING: saving figure to file figures\umapumap_zeisel_vmat2_probability_cluster.pdf

# %%
sc.pl.umap(adata_corr_2, color = 'ClusterName', save = 'umap_zeisel_vmat2_cluster_annot.pdf')
# Out:
# WARNING: saving figure to file figures\umapumap_zeisel_vmat2_cluster_annot.pdf

# %%
adata_f_2 = adata_corr_2[adata_corr_2.obs['batch'] == 'Vmat2-Cre']
calc_Vmat_cluster = calc_celltype_observation(adata_f_2, 'ClusterName')
print(calc_Vmat_cluster)

print((calc_Vmat_cluster/len(adata_f_2.obs_names))*100)
# Out:
#           number_cells
# obs_name
# TEGLU3               4
# TEGLU7              48
# TEGLU8              99
#           number_cells
# obs_name
# TEGLU3        2.649007
# TEGLU7       31.788079
# TEGLU8       65.562914

# %%
distplot_prob_cluster = sns.distplot(adata_f_2.obs['probability'])
plt.show()
fig_cluster = distplot_prob_cluster.get_figure()
fig_cluster.savefig('distplot_prob_cluster.pdf')

# %%
adata_f_2.obs['probability'].mean()
# Out:
# 0.47755492533230914

# %%
adata_w.obs_names = adata_f_2.obs_names
adata_w.obs_names

adata_w.obs['ClusterName'] = adata_f_2.obs['ClusterName']
adata_w.obs['Probable_location'] = adata_f_2.obs['Probable_location']

# %%
sc.pl.umap(adata_w, color='ClusterName', save = 'umap_vmat2_annotated_clusters.pdf')
# Out:
# WARNING: saving figure to file figures\umapumap_vmat2_annotated_clusters.pdf

# %%
result = adata_w.uns['rank_genes_groups']
groups = result['names'].dtype.names
pd.DataFrame({group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'sc
# 7                       0.038762
# 8                       0.042662
# 9                       0.042780
# 10                      0.044878
# 11                      0.046907
# 12                      0.046146
# 13                      0.046146
# 14                      0.048412
# 15                      0.048579
# 16                      0.049035
# 17                      0.049567
# 18                      0.051094
# 19                      0.054491
# 20                      0.058439
# 21                      0.058806
# 22                      0.061318
# 23                      0.061753
# 24                      0.067492
# 25                      0.064058
# 26                      0.068455
# 27                      0.068885
# 28                      0.068203
# 29                      0.068455
# 30                      0.069574
# 31                      0.068885
# 32                      0.071683
# 33                      0.070973
# 34                      0.072137
# 35                      0.070973
# 36                      0.071683
# 37                      0.073751
# 38                      0.074771
# 39                      0.075508

# %%
sc.tl.rank_genes_groups(adata_w, groupby = 'ClusterName')

# %%
sc.tl.dendrogram(adata_w, groupby= 'ClusterName')
sc.pl.rank_genes_groups_stacked_violin(adata_w, n_genes=15, stripplot= True, jitter = 0.4, groupby = 'ClusterName', save = 'stacked_violin_ranked_genes_vmat2_cluster.pdf')
# Out:
# WARNING: saving figure to file figures\stacked_violinstacked_violin_ranked_genes_vmat2_cluster.pdf

# %%
result = adata_w.uns['rank_genes_groups']
groups = result['names'].dtype.names
pd.DataFrame({group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'scores', 'pvals_adj']}).head(50)
# Out:
#       TEGLU3_n  TEGLU3_s  TEGLU3_p       TEGLU7_n  TEGLU7_s  TEGLU7_p  \
# 0       Pcsk1n  4.114220  0.869189            Mtr  4.782478  0.220436
# 1       Rps27l  3.612239  0.869189          Abca4  4.293953  0.331199
# 2          Cpe  3.316373  0.869189  4933438K21Rik  4.237937  0.331199
# 3         Pon2  3.097529  0.869189          Hydin  4.157426  0.331199
# 4         Etfa  2.717981  0.869189          Sfxn4  4.108384  0.331199
# 5        Usmg5  2.685657  0.869189           Cubn  4.008368  0.377130
# 6        Ap2m1  2.576190  0.869189          Usp28  3.979692  0.377130
# 7         Rrp1  2.468914  0.869189          Trak1  3.881660  0.378563
# 8         Fth1  2.435648  0.869189         Slc5a6  3.776904  0.378563
# 9      Sparcl1  2.420703  0.869189          Sf3a3  3.727213  0.378563
# 10        Canx  2.380503  0.869189        Slc36a2  3.701218  0.378563
# 11       Cplx2  2.243818  0.869189         Nap1l4  3.700009  0.378563
# 12       Cox8a  2.228721  0.869189         Mroh2a  3.696775  0.378563
# 13        Sdc4  2.209149  0.869189          Myo1e  3.650527  0.378563
# 14        Mlc1  2.192354  0.869189        Agtpbp1  3.634060  0.378563
# 15        Cst3  2.149870  0.869189         Zbtb40  3.628179  0.378563
# 16       Rps21  2.079154  0.869189          Tectb  3.617373  0.378563
# 17  ERCC-00058  2.006031  0.869189        Pikfyve  3.616254  0.378563
# 18         Dbi  1.990662  0.869189           Ryr3  3.596771  0.378563
# 19        Scg3  1.976739  0.869189         Efcab6  3.594772  0.378563
# 20      Ndufb9  1.961426  0.869189         Golga4  3.585629  0.378563
# 21      Cox6b1  1.950404  0.869189            St5  3.575222  0.378563
# 22       Ncoa1  1.922444  0.869189         Col7a1  3.562757  0.378563
# 23        Scd2  1.908850  0.869189         Pkd2l1  3.560638  0.378563
# 24       Calm1  1.869915  0.869189         Abca13  3.524979  0.378563
# 29         Mrpl28  2.800506  0.070177
# 30           Emg1  2.775436  0.071413
# 31         Hnrnpk  2.751807  0.072878
# 32           Plp2  2.750829  0.073493
# 33          Actg1  2.739294  0.073206
# 34           Swi5  2.733501  0.073636
# 35       Tmem132a  2.732896  0.073636
# 36          Rasa2  2.729882  0.073636
# 37        Gm16039  2.725227  0.074366
# 38            Lbh  2.722320  0.074111
# 39        Adora2b  2.707678  0.075349
# 40          Rbm15  2.707253  0.075580
# 41            Vcp  2.706493  0.075349
# 42       Mir680-2  2.704072  0.078161
# 43  4930449E01Rik  2.688804  0.079739
# 44        Trappc5  2.679590  0.078168
# 45          Grik2  2.654314  0.082712
# 46          Ggta1  2.648276  0.084644
# 47        Tnfsf13  2.638061  0.084909
# 48       AI462493  2.633343  0.083859
# 49           Aoc2  2.618530  0.088623

# %%
sc.pl.stacked_violin(adata_w, var_names = marker_genes, var_group_labels = group_labels, var_group_positions = group_position,
                     stripplot = True, jitter = 0.4, groupby = 'ClusterName', save = 'clusters_marker_genes.pdf' )
# Out:
# WARNING: saving figure to file figures\stacked_violinclusters_marker_genes.pdf
# [<matplotlib.axes._subplots.AxesSubplot at 0x1edb633b5c0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1edb55c7c50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1edc0bab2b0>]

# %%
adata_w_t3 = adata_w[adata_w.obs['ClusterName'] == 'TEGLU3']
per_t3 = percentage_exp(adata_w_t3, marker_genes)
print(per_t3)
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\anndata\core\anndata.py:846: FutureWarning: In anndata v0.7+, arrays contained within an AnnData object will maintain their dimensionality. For example, prior to v0.7 `adata[0, 0].X` returned a scalar and `adata[0, :]` returned a 1d array, post v0.7 they will return two dimensional arrays. If you would like to get a one dimensional array from your AnnData object, consider using the `adata.obs_vector`, `adata.var_vector` methods or accessing the array directly.
#   warn_flatten()
# [('Rorb', 25.0), ('Slc18a2', 0.0), ('Tph1', 0.0), ('Tph2', 0.0), ('Ddc', 0.0), ('Slc17a6', 0.0), ('Slc17a7', 0.0), ('Slc17a8', 0.0), ('Calb1', 0.0), ('Pvrl3', 0.0), ('Npnt', 0.0), ('Ddn', 0.0), ('Rasgrf2', 0.0), ('Scnn1a', 0.0), ('Kcnab3', 0.0), ('Kcnk2', 0.0), ('Plcxd2', 0.0), ('Foxp2', 0.0), ('Syt6', 0.0), ('Sst', 0.0), ('Pvalb', 0.0), ('Calb1', 0.0), ('Cck', 0.0)]

# %%
adata_w_t7 = adata_w[adata_w.obs['ClusterName'] == 'TEGLU7']
per_t7 = percentage_exp(adata_w_t7, marker_genes)
print(per_t7)
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\anndata\core\anndata.py:846: FutureWarning: In anndata v0.7+, arrays contained within an AnnData object will maintain their dimensionality. For example, prior to v0.7 `adata[0, 0].X` returned a scalar and `adata[0, :]` returned a 1d array, post v0.7 they will return two dimensional arrays. If you would like to get a one dimensional array from your AnnData object, consider using the `adata.obs_vector`, `adata.var_vector` methods or accessing the array directly.
#   warn_flatten()
# [('Rorb', 100.0), ('Pvrl3', 58.333333333333336), ('Slc18a2', 41.66666666666667), ('Ddc', 22.916666666666664), ('Kcnk2', 20.833333333333336), ('Slc17a8', 18.75), ('Foxp2', 18.75), ('Npnt', 16.666666666666664), ('Ddn', 16.666666666666664), ('Plcxd2', 16.666666666666664), ('Tph2', 14.583333333333334), ('Slc17a6', 8.333333333333332), ('Calb1', 6.25), ('Scnn1a', 6.25), ('Syt6', 6.25), ('Calb1', 6.25), ('Tph1', 4.166666666666666), ('Kcnab3', 4.166666666666666), ('Slc17a7', 2.083333333333333), ('Rasgrf2', 2.083333333333333), ('Sst', 2.083333333333333), ('Pvalb', 2.083333333333333), ('Cck', 2.083333333333333)]

# %%
adata_w_t8 = adata_w[adata_w.obs['ClusterName'] == 'TEGLU8']
per_t8 = percentage_exp(adata_w_t8, marker_genes)
print(per_t8)
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\anndata\core\anndata.py:846: FutureWarning: In anndata v0.7+, arrays contained within an AnnData object will maintain their dimensionality. For example, prior to v0.7 `adata[0, 0].X` returned a scalar and `adata[0, :]` returned a 1d array, post v0.7 they will return two dimensional arrays. If you would like to get a one dimensional array from your AnnData object, consider using the `adata.obs_vector`, `adata.var_vector` methods or accessing the array directly.
#   warn_flatten()
# [('Rorb', 91.91919191919192), ('Pvrl3', 33.33333333333333), ('Kcnk2', 26.262626262626267), ('Slc18a2', 18.181818181818183), ('Foxp2', 8.080808080808081), ('Plcxd2', 7.07070707070707), ('Calb1', 6.0606060606060606), ('Calb1', 6.0606060606060606), ('Tph2', 5.05050505050505), ('Kcnab3', 5.05050505050505), ('Syt6', 5.05050505050505), ('Ddc', 4.040404040404041), ('Slc17a7', 4.040404040404041), ('Ddn', 4.040404040404041), ('Rasgrf2', 4.040404040404041), ('Scnn1a', 4.040404040404041), ('Pvalb', 4.040404040404041), ('Tph1', 3.0303030303030303), ('Slc17a6', 3.0303030303030303), ('Npnt', 3.0303030303030303), ('Slc17a8', 2.0202020202020203), ('Sst', 2.0202020202020203), ('Cck', 2.0202020202020203)]

# %%
sc.pl.stacked_violin(adata_w, var_names = marker_genes, var_group_labels = group_labels, var_group_positions = group_position,
                     stripplot = True, jitter = 0.4, groupby = 'Probable_location', save = 'location_marker_genes.pdf' )
# Out:
# WARNING: saving figure to file figures\stacked_violinlocation_marker_genes.pdf
# [<matplotlib.axes._subplots.AxesSubplot at 0x1ede2c7a908>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1edb58912b0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1edb45a1b70>]

# %%
adata_w_l23 = adata_w[adata_w.obs['Probable_location'] == 'Cortical pyramidal layer 2/3']
per_l23 = percentage_exp(adata_w_l23, marker_genes)
print(per_l23)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Probable_location'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-187-3305f8c0dcd8> in <module>()
# ----> 1 adata_w_l23 = adata_w[adata_w.obs['Probable_location'] == 'Cortical pyramidal layer 2/3']
#       2 per_l23 = percentage_exp(adata_w_l23, marker_genes)
#       3 per_l23
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Probable_location'

# %%
adata_w_l4 = adata_w[adata_w.obs['Probable_location'] == 'Cortical pyramidal layer 4']
per_l4 = percentage_exp(adata_w_l4, marker_genes)
print(per_l4)
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\anndata\core\anndata.py:846: FutureWarning: In anndata v0.7+, arrays contained within an AnnData object will maintain their dimensionality. For example, prior to v0.7 `adata[0, 0].X` returned a scalar and `adata[0, :]` returned a 1d array, post v0.7 they will return two dimensional arrays. If you would like to get a one dimensional array from your AnnData object, consider using the `adata.obs_vector`, `adata.var_vector` methods or accessing the array directly.
#   warn_flatten()
# [('Rorb', 92.0), ('Pvrl3', 33.0), ('Kcnk2', 27.0), ('Slc18a2', 19.0), ('Foxp2', 8.0), ('Plcxd2', 7.000000000000001), ('Tph2', 6.0), ('Calb1', 6.0), ('Calb1', 6.0), ('Ddc', 5.0), ('Kcnab3', 5.0), ('Syt6', 5.0), ('Slc17a7', 4.0), ('Npnt', 4.0), ('Ddn', 4.0), ('Rasgrf2', 4.0), ('Scnn1a', 4.0), ('Pvalb', 4.0), ('Tph1', 3.0), ('Slc17a6', 3.0), ('Slc17a8', 2.0), ('Sst', 2.0), ('Cck', 2.0)]

# %%
adata_w_l6 = adata_w[adata_w.obs['Probable_location'] == 'Cortical pyramidal layer 6']
per_l6 = percentage_exp(adata_w_l6, marker_genes)
print(per_l6)
# Out:
# C:\Users\hanwe868\AppData\Local\Continuum\anaconda3\lib\site-packages\anndata\core\anndata.py:846: FutureWarning: In anndata v0.7+, arrays contained within an AnnData object will maintain their dimensionality. For example, prior to v0.7 `adata[0, 0].X` returned a scalar and `adata[0, :]` returned a 1d array, post v0.7 they will return two dimensional arrays. If you would like to get a one dimensional array from your AnnData object, consider using the `adata.obs_vector`, `adata.var_vector` methods or accessing the array directly.
#   warn_flatten()
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-115-7fce04786f72> in <module>()
#       1 adata_w_l6 = adata_w[adata_w.obs['Probable_location'] == 'Cortical pyramidal layer 6']
# ----> 2 per_l6 = percentage_exp(adata_w_l6, marker_genes)
#       3 print(per_l6)
#
# <ipython-input-45-037688290c11> in percentage_exp(adata, genes)
#       3     per_list = []
#       4     for gene in genes:
# ----> 5         percentage = len(adata[adata[:, gene].X > 0.25])/len(adata.X)
#       6         per_list.append((gene, percentage*100))
#       7     return sorted(per_list, key=lambda tup: tup[1], reverse = True)
#
# ZeroDivisionError: division by zero
